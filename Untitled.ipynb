# %%
data = [3, 4.5, 9, 9.3]

# %%
import matplotlib.pyplot as plt

#plt.figure().gca().xaxis.set_major_locator(plt.MaxNLocator(integer=True))
#...

plot_1 = plt.plot( list(range(1, len(data) + 1)), data, label='Plot 1')
plot_2 = plt.plot( list(range(1, len(data) + 1)), data, label='Plot 2')
plt.legend()
plt.show()

plot_1 = plt.plot( list(range(1, len(data) + 1)), data, label='qqq 1')
plot_2 = plt.plot( list(range(1, len(data) + 1)), data, label='lll 2')
plt.legend()
plt.show()

# %%
import numpy as np
import cv2

# %%
import os
files = os.listdir("signs-photos/")
print(files)
# Out:
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png']

# %%
for counter, file in enumerate(files):      
    print(file)
    bgr_img = cv2.imread('signs-photos/' + file) 
    rgb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)

    image = cv2.resize(rgb_img,(32,32))
    image = np.asarray(image, dtype=np.uint8)
    plt.imshow(image)
    plt.show()
    
    #X_Images[counter] = image
# Out:
# 1.png
# 2.png
# 3.png
# 4.png
# 5.png
# 6.png
# 7.png

# %%
Y_photos = [2, 17]

# %%
q = np.array([3, 3, 2, 2, 1, 3, 2 , 1, 3,3 ,3, 3,3 ,2 ,2, 3])

# %%
plt.hist(q, bins = range(0,5))
# Out:
# (array([ 0.,  2.,  5.,  9.]),
#  array([0, 1, 2, 3, 4]),
#  <a list of 4 Patch objects>)

# %%
plt.show()

# %%
labels = ["a", "b", "c", "d"]
lab = ['1', '4', '5', '8']
io = [2, 7, 3, 5]
bar = plt.barh(np.arange(len(labels)), io)
bar.set_yticklabels(labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-e5bbe9e6a7ce> in <module>()
#       3 io = [2, 7, 3, 5]
#       4 bar = plt.barh(np.arange(len(labels)), io)
# ----> 5 bar.set_yticklabels(labels)
#       6 plt.show()
#
# AttributeError: 'BarContainer' object has no attribute 'set_yticklabels'
